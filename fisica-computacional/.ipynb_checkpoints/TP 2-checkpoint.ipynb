# %% [markdown]
# # TP 2

# %%
#Bibliotecas
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl

# %%
pip install Ipython
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
dados = pd.read_csv('sunspots.txt', sep='\s+')

# %%
dados.head()
# Out:
#    0  58.0
# 0  1  62.6
# 1  2  70.0
# 2  3  55.7
# 3  4  85.0
# 4  5  83.5

# %% [markdown]
# ###### %ls 'newman/dados/sunspots.txt'

# %%
data = np.loadtxt('newman/dados/sunspots.txt')
print("linhas x colunas", data.shape)
# Out:
# linhas x colunas (3143, 2)

# %%
data[:5,:]
# primeira parte as linhas , depois as colunas
#ou seja todas as colunas e até a 5 linhas
# Out:
# array([[ 0. , 58. ],
#        [ 1. , 62.6],
#        [ 2. , 70. ],
#        [ 3. , 55.7],
#        [ 4. , 85. ]])

# %% [markdown]
# *Exercicio 1*

# %%
fig, ax = plt.subplots(figsize = (4,3))

x = data[:,0]# apenas o conteudo da primeira coluna
y = data[:,1]# agora é o conteudo da segunda coluna

ax.plot(x , y)

plt.show()

# %%
fig, ax = plt.subplots(1,2)

x = data[0:1000,0]# apenas o conteudo da primeira coluna
y = data[0:1000,1]# agora é o conteudo da segunda coluna

ax.scatter(x , y,marker ='o', color = 'blue', facecolor = 'w')
ax.set(title = "Manchas Solares")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_5618/2651182875.py in <module>
#       4 y = data[0:1000,1]# agora é o conteudo da segunda coluna
#       5
# ----> 6 ax.scatter(x , y,marker ='o', color = 'blue', facecolor = 'w')
#       7 ax.set(title = "Manchas Solares")
#       8
#
# AttributeError: 'numpy.ndarray' object has no attribute 'scatter'

# %%
# cálculo das medias moveis
r = 5
N = 1000
Y = np.zeros(N)

for i in range(-r,r+1):
    som = data[5+i : N+5+i , 1]
    Y += som
    
media_m = (1/(2*r + 1))*Y

fig, ax = plt.subplots()

x = data[5:1005,0]# apenas o conteudo da primeira coluna
y = data[5:1005,1]# agora é o conteudo da segunda coluna

ax.scatter(x , y,marker ='o', color = 'blue', facecolor = 'w')
ax.set(title = "Manchas Solares")
ax.plot(x,media_m,color = 'red')

plt.show()

# %% [markdown]
# *Exxercicio 2*

# %%
o = np.linspace(0,2*np.pi,1000)
x = 2*np.cos(o) + np.cos(2*o)
y = 2*np.sin(o) + np.sin(2*o)
plt.plot(x,y)

# %%
#x = rcos(o) logo 
o2 = np.linspace(0,10*np.pi,1000)
x2 = (o2**2)*np.cos(o2)
y2 = (o2**2)*np.sin(o2)
plt.plot(x2,y2)
r = o**2
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.plot(o2, r)

# %%
# outra solucao mais elegante
r = o**2
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.plot(o2, r)

# %%
o3 = np.arange(0,24*np.pi,0.01)
x3 = (np.exp(np.cos(o3)) - (2 * np.cos(4 * o3)) + (np.sin(o3/12)**5))*np.cos(o3)
y3 = (np.exp(np.cos(o3)) - (2 * np.cos(4 * o3)) + (np.sin(o3/12)**5))*np.sin(o3)
plt.plot(x3,y3)

# %%
# outra solucao 
r = np.exp(np.cos(o3)) - (2 * np.cos(4 * o3)) + (np.sin(o3/12)**5)
fig , ax = plt.subplots(subplot_kw = {'projection' : 'polar'})
ax.plot(o3,r)

# %% [markdown]
# *Execicio 3*

# %%
data2 = np.loadtxt('newman/dados/stm.txt')
data2.shape
# Out:
# (663, 676)

# %%
#import matplotlib.colormaps as cp
pl.imshow(data2)
#pl.grey() mostra cinza
#pl.jet() #default
#pl.hot() heat map
#pl.spectral() nao funcionou
#pl.bone() #e um raio x
#pl.hsv() raibow
#cp.flag()
pl.show()

# %% [markdown]
# *exercicio 4*

# %%
from vpython import *
scene = canvas()
sphere()
# Out:
# <div id="glowscript" class="glowscript"></div>

# %%
from vpython import *
L = 1
R = 0.3
scene = canvas()
for i in range(-L,L+1):
    for j in range(-L,L+1):
        for k in range(-L,L+1):
            if (i + j + k) % 2 == 0:
                sphere(pos=vector(i,j,k),radius = R,color = color.green)
            else:
                 sphere(pos=vector(i,j,k),radius = R,color = color.blue)
# Out:
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# *Exercício 5*

# %%
# esfera que vai de um lugar para o outro
from vpython import *
scene = canvas()
s = sphere(pos= vector(0,0,0))
rate(100000)
s.pos = vector(1,4,3)
# Out:
# <div id="glowscript" class="glowscript"></div>

# %%
from vpython import *
scene = canvas()
s = sphere(pos=vector(1,0,0),radius=0.1)
for theta in arange(0,10*pi,0.1):
    rate(30)
    x = np.cos(theta)
    y = np.sin(theta)
    s.pos = vector(x,y,0)
# Out:
# <div id="glowscript" class="glowscript"></div>

# %%
import numpy as np
from vpython import *
scene = canvas()
#sol
rsol = 1.391
sol = sphere(pos=vector(0,0,0),radius=rsol,color = color.yellow) 
# mecurio
rmer = 0.0244
romer = 3*0.579
vmer = 1
mercurio = sphere(pos=vector(romer,0,0),radius=rmer,color = color.red)
#venus
rv = 0.06052
rov = 3*1.082
vv = 0.391
venus = sphere(pos=vector(rov,0,0),radius=rv,color = color.orange)
#terra
rt = 0.06371
rot = 3*1.496
vt = 0.241
terra = sphere(pos=vector(rot,0,0),radius=rt,color = color.blue)
#marte
rm = 0.03386
rom = 3*2.279
vm = 0.128
marte = sphere(pos=vector(rom,0,0),radius=rm,color = color.orange)
#jupites
rj = 0.69173
roj = 3*7.785
vj = 0.0203
jupiter = sphere(pos=vector(roj,0,0),radius=rj,color = color.orange)
#saturno
rs = 0.57316
ros = 3*14.334
vs = 0.008
saturno = sphere(pos=vector(ros,0,0),radius=rs,color = color.blue)

for t in arange(0,1000*pi,0.1):
    rate(10)# o rate só muda a velocidade da animação não da minhas esfera
    # mecúrio
    x = romer*np.cos(vmer*t)
    y = romer*np.sin(vmer*t)
    mercurio.pos = vector(x,y,0)
    #venus
    x2 = rov*np.cos(vv*t)
    y2 = rov*np.sin(vv*t)
    venus.pos = vector(x2,y2,0)
    #terra
    x3 = rot*np.cos(vt*t)
    y3 = rot*np.sin(vt*t)
    terra.pos = vector(x3,y3,0)
    #marte
    x4 = rom*np.cos(vm*t)
    y4 = rom*np.sin(vm*t)
    marte.pos = vector(x4,y4,0)
    #jupiter
    x5 = roj*np.cos(vj*t)
    y5 = roj*np.sin(vj*t)
    jupiter.pos = vector(x5,y5,0)
    #saturno
    x6 = ros*np.cos(vs*t)
    y6 = ros*np.sin(vs*t)
    
    saturno.pos = vector(x6,y6,0)
# Out:
# <div id="glowscript" class="glowscript"></div>
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# *Exercício 6*

# %%
r = np.arange(0,4,0.01)#40
I = 1000
l = 400
x = np.zeros((I,l))
x[0:] = 0.5
for i in range (1,I):
    x[i,] = r *x[i - 1,]*(1 - x[i - 1,])
#for k in range (I):
    plt.scatter(r, x[i,], s=1, c='b', marker='.')

# %% [markdown]
# *Exercício 7*

# %%
N = 1000
x = np.linspace(-2,2,N)
y = np.linspace(-2,2,N)
r,i = np.meshgrid (x,y)
# vou criar uma grade com cada ponto no meu gráfico
c = r + 1j*i

# definir o numero deinterações
numi = 100

zx = np.zeros_like(c)
zy = np.zeros_like(c)


for _ in range(numi):
    zx,zy  = np.clip(zx**2 - zy**2 + r,-1e10,1e10) ,np.clip( 2*zx*zy + i,-1e10,1e10)

mandelbrot_set = np.sqrt(zx**2 + zy**2) < 2
plt.imshow(mandelbrot_set, extent=(x.min(), x.max(), y.min(), y.max()), cmap='gray', origin='lower')
plt.colorbar()
plt.title('Conjunto de Mandelbrot')
plt.xlabel('Parte Real')
plt.ylabel('Parte Imaginária')
plt.show()
